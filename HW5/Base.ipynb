# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('churn_prediction_data/train.csv')

# %%
df_train
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0           551    15806307   Trevisano          720     Spain    Male   38
# 1          6897    15709621      Martin          682    France  Female   54
# 2          4588    15619340      Palmer          672    France  Female   31
# 3           291    15620746  Napolitani          592     Spain  Female   40
# 4          1673    15646372         Yao          753     Spain    Male   42
# ...         ...         ...         ...          ...       ...     ...  ...
# 7995       5345    15584532          Yu          568    France  Female   35
# 7996       5837    15606641        Liao          602   Germany  Female   45
# 7997       7335    15739692       Ferri          679     Spain  Female   43
# 7998       9552    15791373     Worsnop          715    France    Male   38
# 7999        178    15739931      Ibekwe          600    France  Female   42
#
# ...

# %%
df_train.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 12))

plt.subplot(321)
sns.countplot(x = df_train.Gender, hue = df_train.Exited)

plt.subplot(322)
sns.countplot(x = df_train.Geography, hue = df_train.Exited)

plt.subplot(323)
sns.countplot(x = df_train.Tenure, hue = df_train.Exited)

plt.subplot(324)
sns.countplot(x = df_train.NumOfProducts, hue = df_train.Exited)

plt.subplot(325)
sns.countplot(x = df_train.HasCrCard, hue = df_train.Exited)

plt.subplot(326)
sns.countplot(x = df_train.IsActiveMember, hue = df_train.Exited)
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %%
plt.figure(figsize=(13, 4))

plt.subplot(121)
sns.countplot(x = df_train.Gender)

plt.subplot(122)
sns.countplot(x = df_train.Exited, hue = df_train.Gender)
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='count'>

# %%
plt.figure(figsize=(13, 4))

plt.subplot(121)
sns.countplot(x = df_train.Geography)

plt.subplot(122)
sns.countplot(x = df_train.Exited, hue = df_train.Geography)
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='count'>

# %%
plt.figure(figsize=(13, 4))

plt.subplot(121)
sns.countplot(x = df_train.NumOfProducts)

plt.subplot(122)
sns.countplot(x = df_train.NumOfProducts, hue = df_train.Exited)
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='count'>

# %%
plt.figure(figsize=(13, 4))

plt.subplot(121)
sns.countplot(x = df_train.IsActiveMember)

plt.subplot(122)
sns.countplot(x = df_train.Exited, hue = df_train.IsActiveMember)
# Out:
# <AxesSubplot:xlabel='Exited', ylabel='count'>

# %%
sns.histplot(df_train.Age, binwidth=5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(13, 4))

plt.subplot(121)
sns.histplot(df_train[df_train.Exited==0].Age, binwidth=5)

plt.subplot(122)
sns.histplot(df_train[df_train.Exited==1].Age, binwidth=5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(16, 4))

plt.subplot(131)
sns.histplot(df_train.Age, binwidth=5).set_title('All customers')

plt.subplot(132)
sns.histplot(df_train[df_train.Exited==0].Age, binwidth=5).set_title('Customer does not leave (Exited=0)')

plt.subplot(133)
sns.histplot(df_train[df_train.Exited==1].Age, binwidth=5).set_title('Customer eventually leave (Exited=1)')
# Out:
# Text(0.5, 1.0, 'Customer eventually leave (Exited=1)')

# %%
sns.histplot(df_train.CreditScore, binwidth=50)
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Count'>

# %%
plt.figure(figsize=(13, 4))

plt.subplot(121)
sns.histplot(df_train[df_train.Exited==0].CreditScore, binwidth=50)

plt.subplot(122)
sns.histplot(df_train[df_train.Exited==1].CreditScore, binwidth=50)
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Count'>

# %%
plt.figure(figsize=(13, 15))

plt.subplot(311)
sns.histplot(df_train.Balance).set_title('All customers')

plt.subplot(312)
sns.histplot(df_train[df_train.Exited==0].Balance).set_title('Customer does not leave (Exited=0)')

plt.subplot(313)
sns.histplot(df_train[df_train.Exited==1].Balance).set_title('Customer eventually leave (Exited=1)')
# Out:
# Text(0.5, 1.0, 'Customer eventually leave (Exited=1)')

# %%
plt.figure(figsize=(13, 15))

plt.subplot(311)
sns.histplot(df_train.EstimatedSalary).set_title('All customers')

plt.subplot(312)
sns.histplot(df_train[df_train.Exited==0].EstimatedSalary).set_title('Customer does not leave (Exited=0)')

plt.subplot(313)
sns.histplot(df_train[df_train.Exited==1].EstimatedSalary).set_title('Customer eventually leave (Exited=1)')
# Out:
# Text(0.5, 1.0, 'Customer eventually leave (Exited=1)')
